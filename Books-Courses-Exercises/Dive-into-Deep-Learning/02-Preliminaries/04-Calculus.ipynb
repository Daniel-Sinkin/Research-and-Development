# %%
from matplotlib import pyplot as plt
from matplotlib_inline import backend_inline

import numpy as np
import pandas as pd
import tensorflow as tf

from d2l import tensorflow as d2l

from printing import *
# Out:
# 2023-04-28 22:48:08.649939: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-28 22:48:08.689864: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-28 22:48:08.690341: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-28 22:48:09.306936: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def f(x):
    return x ** 3 - 1 / x


x = np.arange(0.2, 1.8, 0.02)
plot(x, [x ** 3 - 1 / x, 4 * x - 4], 'x', 'f(x)', legend=['f(x)', 'Tangent line (x=1)'])
