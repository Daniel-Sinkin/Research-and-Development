# %%
import numpy as np
import matplotlib.pyplot as plt

import scripts

for n, p in zip([10, 10, 100, 9], [1/2, 1/8, 0.03, 4/5]):
    scripts.plotBinomial(n, p, show = True, save = True)

# %%
for n, p in zip([10, 10, 100, 9], [1/2, 1/8, 0.03, 4/5]):
    plotBinomial(n, p, show = True, save = True)
